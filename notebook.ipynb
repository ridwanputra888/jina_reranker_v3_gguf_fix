:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3145912 (3.0M)
# Saving to: ‘projector.safetensors’
#
# projector.safetenso 100%[===================>]   3.00M  9.53MB/s    in 0.3s
#
# 2025-11-17 11:20:36 (9.53 MB/s) - ‘projector.safetensors’ saved [3145912/3145912]

# %%
# !wget https://huggingface.co/jinaai/jina-reranker-v3-GGUF/resolve/main/jina-reranker-v3-Q8_0.gguf
# Out:
# --2025-11-17 11:16:22--  https://huggingface.co/jinaai/jina-reranker-v3-GGUF/resolve/main/jina-reranker-v3-Q8_0.gguf
# Resolving huggingface.co (huggingface.co)... 3.168.203.95, 3.168.203.88, 3.168.203.106, ...
# Connecting to huggingface.co (huggingface.co)|3.168.203.95|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cas-bridge.xethub-eu.hf.co/xet-bridge-eu/68e18629d015291f3f4c60b2/79925a29d0d9ddd1f048fadf2e55bfbb2d13be8dd5c6f74e3f360f1ede60af53?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=cas%2F20251117%2Feu-west-3%2Fs3%2Faws4_request&X-Amz-Date=20251117T041623Z&X-Amz-Expires=3600&X-Amz-Signature=98d05fb5c1f953cb23cd0144219f2a58c7ac8ccae843b242831b176c72cba12e&X-Amz-SignedHeaders=host&X-Xet-Cas-Uid=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27jina-reranker-v3-Q8_0.gguf%3B+filename%3D%22jina-reranker-v3-Q8_0.gguf%22%3B&x-id=GetObject&Expires=1763356583&Policy=&Signature=uVqrAWYPZhjDL4q0dA%7Emvx4f9MdRyN11eVReKYBdMccpC8eWVjwpCWlz6uPdIIQk6gJwZ7%7Eqf0T3bLCFmQHbr4fr5Cx1pQ9wTfEp1MYqsaITruVE5Hr0HCVk8kR5S4Upt1P5SswY%7E7f%7EYXfsBFOUQTSKqOD1ynChkprwfCFfi3eHCM3XzQMimAQEbuzUFMDYqvAaKOeykHTD%7ES8FSfQX-G7XKv%7EpCbOB8Hoz8FYCOTjVWBDMV284rw1rtNjod9l7-v6iDGMvNdtJx738iqktUDO-Z1lKanhXhJGKDGg5YnZX7nLTpIeOpu-4Z2T-D-ITVnCQM41OK%7Ey0vIY9mgcj3g__&Key-Pair-Id=K1A43T5X783861 [following]
# --2025-11-17 11:16:23--  https://cas-bridge.xethub-eu.hf.co/xet-bridge-eu/68e18629d015291f3f4c60b2/79925a29d0d9ddd1f048fadf2e55bfbb2d13be8dd5c6f74e3f360f1ede60af53?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=cas%2F20251117%2Feu-west-3%2Fs3%2Faws4_request&X-Amz-Date=20251117T041623Z&X-Amz-Expires=3600&X-Amz-Signature=98d05fb5c1f953cb23cd0144219f2a58c7ac8ccae843b242831b176c72cba12e&X-Amz-SignedHeaders=host&X-Xet-Cas-Uid=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27jina-reranker-v3-Q8_0.gguf%3B+filename%3D%22jina-reranker-v3-Q8_0.gguf%22%3B&x-id=GetObject&Expires=1763356583&Policy=&Signature=uVqrAWYPZhjDL4q0dA%7Emvx4f9MdRyN11eVReKYBdMccpC8eWVjwpCWlz6uPdIIQk6gJwZ7%7Eqf0T3bLCFmQHbr4fr5Cx1pQ9wTfEp1MYqsaITruVE5Hr0HCVk8kR5S4Upt1P5SswY%7E7f%7EYXfsBFOUQTSKqOD1ynChkprwfCFfi3eHCM3XzQMimAQEbuzUFMDYqvAaKOeykHTD%7ES8FSfQX-G7XKv%7EpCbOB8Hoz8FYCOTjVWBDMV284rw1rtNjod9l7-v6iDGMvNdtJx738iqktUDO-Z1lKanhXhJGKDGg5YnZX7nLTpIeOpu-4Z2T-D-ITVnCQM41OK%7Ey0vIY9mgcj3g__&Key-Pair-Id=K1A43T5X783861
# Resolving cas-bridge.xethub-eu.hf.co (cas-bridge.xethub-eu.hf.co)... 18.244.51.127, 18.244.51.47, 18.244.51.6, ...
# Connecting to cas-bridge.xethub-eu.hf.co (cas-bridge.xethub-eu.hf.co)|18.244.51.127|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 640050528 (610M)
# Saving to: ‘jina-reranker-v3-Q8_0.gguf’
#
# jina-reranker-v3-Q8 100%[===================>] 610.40M  9.08MB/s    in 67s
#
# 2025-11-17 11:17:30 (9.14 MB/s) - ‘jina-reranker-v3-Q8_0.gguf’ saved [640050528/640050528]

# %%
from rerank import GGUFReranker

# Initialize reranker
reranker = GGUFReranker(
    model_path="jina-reranker-v3-Q8_0.gguf",
    projector_path="projector.safetensors",
    llama_embedding_path="./llama-embedding",
    llama_tokenize_path="./llama-tokenize"
)

# Rerank documents
query = "What is the capital of France?"
documents = [
    "Paris is the capital and largest city of France.",
    "Berlin is the capital of Germany.",
    "The Eiffel Tower is located in Paris."
]

results = reranker.rerank(query, documents)

for result in results:
    print(f"Score: {result['relevance_score']:.4f}, Doc: {result['document'][:50]}...")
# Out:
# Score: 0.4059, Doc: Paris is the capital and largest city of France....
# Score: -0.0821, Doc: The Eiffel Tower is located in Paris....
# Score: -0.1350, Doc: Berlin is the capital of Germany....

# %%
from rerank import GGUFReranker

# Initialize reranker
reranker = GGUFReranker(
    model_path="jina-reranker-v3-Q8_0.gguf",
    projector_path="projector.safetensors",
    llama_embedding_path="./llama-embedding",
    llama_tokenize_path="./llama-tokenize"
)

# Rerank documents
query = "Apa ibu kota Perancis?"
documents = [
    "Paris adalah ibu kota dan kota terbesar di Perancis.",
    "Berlin adalah ibu kota Jerman.",
    "Menara Eiffel terletak di Paris."
]

results = reranker.rerank(query, documents)

for result in results:
    print(f"Score: {result['relevance_score']:.4f}, Doc: {result['document'][:50]}...")
# Out:
# Score: 0.3942, Doc: Paris adalah ibu kota dan kota terbesar di Peranci...
# Score: -0.0864, Doc: Menara Eiffel terletak di Paris....
# Score: -0.1263, Doc: Berlin adalah ibu kota Jerman....
